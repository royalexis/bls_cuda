# %%
import numpy as np
import bls_cuda as gbls

# %%
gbls_inputs = gbls.gbls_inputs_class() # Initialize needed inputs

# gbls_inputs.filename = "klc11446443.d.dat" #Test light-curve
tic = 29991541
gbls_inputs.lcdir    = "/opt/data2/TESS/ffisearch/cvzsearch_yr1/cvz1pt003/tlc"+str(tic)+"/"
gbls_inputs.filename = "tlc"+str(tic)+"_5.dn.dat"

# Remove any offset from time stamps
gbls_inputs.zerotime = 1325.0 # 54900.0 - 0.5

# %%
gbls_inputs.plots = 1
gbls_ans = gbls.bls(gbls_inputs)
# Out:
# Array size: 0.562184 GB
# 100%|██████████| 26/26 [00:12<00:00,  2.12it/s]

# %%
print(gbls_ans.bper, gbls_ans.epo, gbls_ans.bpower, gbls_ans.snr, gbls_ans.tdur, gbls_ans.depth)
# Out:
# 2.4834148982266457 0.4498200799048391 12.012212187572064 13.247374571189509 0.17632245777409183 0.0006942877543174827
